# %% [markdown]
# # Beatriz Balan Fiuza

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe = pd.read_csv("stroke_dataset_limpio.csv",sep=";")
dataframe = dataframe.dropna()
clasificadores = ["yes", "no"]

# %%
dataframe.head(10)
dataframe.describe()
dataframe.groupby("Stroke").size()
# Out:
# Stroke
# 0    4700
# 1     209
# dtype: int64

# %%
import seaborn as sb
sb.catplot(x = "Stroke",data=dataframe,kind="count",height=2.5, aspect=.8)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
for column in dataframe.select_dtypes(include=['object']).columns:
    dataframe[column] = label_encoder.fit_transform(dataframe[column])

# %%
y = dataframe["Stroke"]
x = dataframe.drop("Stroke", axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
knn_mm.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
predicciones = knn_mm.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
tn, fp, fn, tp = confusion_matrix(y_test,predicciones).ravel()

# %%
print(tn, fp, fn, tp)
# Out:
# 900 29 50 3

# %%
sns.heatmap(confusion_matrix(y_test,predicciones), annot=True, fmt="d")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
# Out:
# Text(50.722222222222214, 0.5, 'True')

# %%
print(classification_report(y_test,predicciones,target_names=clasificadores))
# Out:
#               precision    recall  f1-score   support
#
#          yes       0.95      0.97      0.96       929
#           no       0.09      0.06      0.07        53
#
#     accuracy                           0.92       982
#    macro avg       0.52      0.51      0.51       982
# weighted avg       0.90      0.92      0.91       982

# %%
tasa_error = []
for i in range(1,25):
    knn_mm = KNeighborsClassifier(n_neighbors=i)
    knn_mm.fit(x_train,y_train)
    prediccion_i = knn_mm.predict(x_test)
    tasa_error.append(np.mean (prediccion_i != y_test))

# %%
valores = range (1,25)
plt.plot(valores, tasa_error, color="green", marker="o", markerfacecolor = "red", markersize="8")

# %%
knn_mm = KNeighborsClassifier(n_neighbors=10)

# %%
knn_mm.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
predicciones = knn_mm.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,predicciones))
print(classification_report(y_test,predicciones,target_names=clasificadores))
# Out:
# [[929   0]
#  [ 53   0]]
#               precision    recall  f1-score   support
#
#          yes       0.95      1.00      0.97       929
#           no       0.00      0.00      0.00        53
#
#     accuracy                           0.95       982
#    macro avg       0.47      0.50      0.49       982
# weighted avg       0.89      0.95      0.92       982
# C:\Users\Pessoal\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Pessoal\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
print(knn_mm.predict([[4,65,3]]))
print(knn_mm.predict([[3,30,2]]))
print(knn_mm.predict([[5,70,3]]))
print(knn_mm.predict([[5,20,2]]))
print(knn_mm.predict([[2,70,1]]))
print(knn_mm.predict([[5,10,1]]))
print(knn_mm.predict([[4,65,1]]))
# Out:
# C:\Users\Pessoal\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 print(knn_mm.predict([[4,65,3]]))
#       2 print(knn_mm.predict([[3,30,2]]))
#       3 print(knn_mm.predict([[5,70,3]]))
#
# File ~\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:271, in KNeighborsClassifier.predict(self, X)
#     268         return self.classes_[np.argmax(probabilities, axis=1)]
#     269     # In that case, we do not need the distances to perform
#     270     # the weighting so we do not compute them.
# --> 271     neigh_ind = self.kneighbors(X, return_distance=False)
#     272     neigh_dist = None
#     273 else:
#
# ...

# %%
print(knn_mm.predict_proba([[4,65,3]]))
print(knn_mm.predict_proba([[3,30,2]]))
print(knn_mm.predict_proba([[5,70,3]]))
print(knn_mm.predict_proba([[5,20,2]]))
print(knn_mm.predict_proba([[2,70,1]]))
print(knn_mm.predict_proba([[5,10,1]]))
print(knn_mm.predict_proba([[4,65,1]]))
# Out:
# C:\Users\Pessoal\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 print(knn_mm.predict_proba([[4,65,3]]))
#       2 print(knn_mm.predict_proba([[3,30,2]]))
#       3 print(knn_mm.predict_proba([[5,70,3]]))
#
# File ~\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:366, in KNeighborsClassifier.predict_proba(self, X)
#     362         return probabilities
#     364     # In that case, we do not need the distances to perform
#     365     # the weighting so we do not compute them.
# --> 366     neigh_ind = self.kneighbors(X, return_distance=False)
#     367     neigh_dist = None
#     368 else:
#
# ...
